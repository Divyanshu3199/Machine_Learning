# %% [markdown]
# # K Means Clustering Implementation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_blobs
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
x,y = make_blobs(n_samples = 1000, centers = 3, n_features = 2,random_state = 23)

# %%
plt.scatter(x[:,0],x[:,1])
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.33,random_state = 42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((670, 2), (330, 2), (670,), (330,))

# %%
from sklearn.cluster import KMeans

# %%
# Elbow method to select k value
wcss  = []
for k in range(1,11):
    Kmeans = KMeans(n_clusters = k,init = 'k-means++')
    Kmeans.fit(x_train)
    wcss.append(Kmeans.inertia_)

# %%
wcss
# Out:
# [34827.57682552022,
#  7935.437286145416,
#  1319.2730531585607,
#  1140.4677884655127,
#  992.0708509383512,
#  893.0633120916282,
#  764.8745286454578,
#  699.1207373884818,
#  592.149899726398,
#  550.8880426181729]

# %%
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters = 3,init = "k-means++")

# %%
y_pred = kmeans.fit_predict(x_train)

# %%
plt.scatter(x_train[:,0],x_train[:,1],c = y_pred)
plt.show()

# %%
# knee locator
# !pip install kneed
# Out:
# Requirement already satisfied: kneed in c:\users\riyan\anaconda3\lib\site-packages (0.8.5)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\riyan\anaconda3\lib\site-packages (from kneed) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\riyan\anaconda3\lib\site-packages (from kneed) (1.13.1)

# %%
from kneed import KneeLocator

# %%
k1 = KneeLocator(range(1,11),wcss,curve = 'convex',direction = 'decreasing')

# %%
k1.elbow
# Out:
# 3

# %%
# Checkking accuracy
from sklearn.metrics import silhouette_score

# %%
kmeans = KMeans(n_clusters = 3, init = "k-means++")
kmeans.fit(x_train)
score = silhouette_score(x_train,kmeans.labels_)

# %%
print(score)
# Out:
# 0.8071181203797672
